# %%
# Set back end processor for MATLAB
# %matplotlib inline

# %%
# Import dependencies and check matplotlib version
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#same syntax as line chart but with additional "o" input param
plt.plot(x_axis, y_axis, "o")

# %%
#aka scatter
plt.scatter(y_axis,x_axis,c="red",label="Chicago")

#add axis labels and title
plt.xlabel("Fare($)")
plt.ylabel("Date")
plt.title('PyBer Fare by Month')

# set x axis limit
plt.xlim(0,50)

# Invert y axis labels
plt.gca().invert_yaxis()

#add legend
plt.legend()

# %%
#bubble chart, using color and size (s) as 3rd and 4th dimensions
# y_axis_larger = []
# for data in y_axis:
#     y_axis_larger.append(data*3)

# plt.scatter(x_axis, y_axis, s=y_axis_larger)

#use list comprehension
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
#Scatter plot in OO interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#Bubble chart in OO interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, 
#            color="skyblue", 
#            edgecolor="black", 
#            alpha=0.2, 
#            linewidth=2, 
#            s=[i*5 for i in y_axis], 
           label="Boston")
ax.title="PyBer Fare by Month"
ax.legend()
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x0000023D0A3C6A60> (for post_execute):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     137             def post_execute():
#     138                 if matplotlib.is_interactive():
# --> 139                     draw_all()
#     140
#     141             # IPython >= 2
#
# ~\anaconda3\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     135         for manager in cls.get_all_fig_managers():
#     136             if force or manager.canvas.figure.stale:
# --> 137                 manager.canvas.draw_idle()
#     138
#     139
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    2053         if not self._is_idle_drawing:
# ...
